# %% [markdown]
# # filter dataset and clean
#
# <img src="https://upload.wikimedia.org/wikipedia/en/thumb/6/6d/Nvidia_image_logo.svg/200px-Nvidia_image_logo.svg.png" width="90px" align="right" style="margin-right: 0px;">
#
# How to filter dataset to contain only specific keywords

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd


# Read CSV files
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets/jd_source_c_2_filtered_clean_bank_030622.csv')


to_drop = ['Unnamed: 0', 'job_desc']

df.drop(to_drop, inplace=True, axis=1)
df.head()
print(df.head())
# Out:
#    Unnamed: 0.1                                          job_title  \
# 0            81  SVP / VP, Data Scientist, Business Analytics, ...
# 1           106                         Business Analyst (Banking)
# 2           136  Associate / Analyst, Business Banking Relation...
# 3           145  ED/SVP, UX Designer – Digital Banking, Consume...
# 4           146  Associate / Analyst, Corporate Action Processo...
#
#                                                skill  \
# 0  SVP / VP\nData Scientist\nBusiness Analytics\n...
# 1                          Business Analyst\nBanking
# 2  Associate / Analyst\nBusiness Banking Relation...
# 3  ED/SVP\nUX Designer – Digital Banking\nConsume...
# 4  Associate / Analyst\nCorporate Action Processo...
#
#                       Industry                                 Function  \
# 0     IT/ Computers - Software                                       IT
# 1  Banking/ Financial Services                                       IT
# ...

# %%
mask = df['job_title'].str.contains('bank', case=False, na=False)
df[mask]

print(df[mask])

df[mask].to_csv(r'jd_source_c_2_filtered_clean_drop_bank_030622.csv')
# Out:
#      Unnamed: 0.1                                          job_title  \
# 0              81  SVP / VP, Data Scientist, Business Analytics, ...
# 1             106                         Business Analyst (Banking)
# 2             136  Associate / Analyst, Business Banking Relation...
# 3             145  ED/SVP, UX Designer – Digital Banking, Consume...
# 4             146  Associate / Analyst, Corporate Action Processo...
# ..            ...                                                ...
# 162          4811  Hiring-Project Manager-Cash Management-for one...
# 163          4940                      IT Support Engineer (Banking)
# 164          5163  Hiring Project Manager (Banking Domain) for on...
# 165          5331      Deployment Assistant ( Banking Applications )
# 166          5344            Solution Architech with Digital Banking
#
#                                                  skill  \
# 0    SVP / VP\nData Scientist\nBusiness Analytics\n...
# ...
