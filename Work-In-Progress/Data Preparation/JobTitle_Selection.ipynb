# %% [markdown]
# **Selecting specific job title.**

# %%
import pandas as pd


data= pd.read_csv("jd_source_b.csv") # Select your source csv.
df = pd.DataFrame(data)
cols = [2,1,3] # Will only select 'company, job_title & job_description'. 2,1,3 is the column arrangement.
df = df[df.columns[cols]]

df2 = df[df['job_title'].str.contains('Physiotherapist')] #Input the job title you want
df2 = df2.rename(columns={'job_title': 'Job Title', 'company': 'Company', 'job_desc': 'Job Description'}) #This will format the header

df2.to_csv('Job_Physiotherapist.csv', index=False) #Rename accordingly and save into a new csv for editing
df2.to_excel('Job_Physiotherapist.xls', index=False)

df2.head(20)
# Out:
#                                                 Company  \
# 103   MCi CAREER SERVICES PTE LTD\n\n    \t\t\t\t\t\...
# 520   JOBSTUDIO PTE LTD\n\n    \t\t\t\t\t\t\t     \n...
# 594   Capita Pte Ltd - Business Support 3\n\n    \t\...
# 741   PERSOL Singapore (a division of Capita Pte Ltd...
# 890   Capita Pte Ltd - Business Support 3\n\n    \t\...
# 961                             Mount Alvernia Hospital
# 976                  Rotary Engineering Private Limited
# 1123                DFS VENTURE SINGAPORE (PTE) LIMITED
# 1141                                        StarHub Ltd
# 1484         Colliers International (Singapore) Pte Ltd
# 1658                      COSL Drilling Pan Pacific Ltd
# 1729                             SAWINDO AGRI PTE. LTD.
# 1806         SINGAPORE AERO ENGINE SERVICES P.T.E L.T.D
# 1975                        PANZER TECHNOLOGY PTE. LTD.
# 2185  JOBSTUDIO PTE LTD\n\n    \t\t\t\t\t\t\t     \n...
# 2192  FSK Advisory Pte Ltd\n\n    \t\t\t\t\t\t\t    ...
# 2226  Capita Pte Ltd – Temp & Contract    \t\t\t\t\t...
# 2363  RECRUIT EXPRESS PTE LTD\n\n    \t\t\t\t\t\t\t ...
# 2577  Cadmus Resources\n\n    \t\t\t\t\t\t\t     \n\...
# 2799  TempServ Pte Ltd\n\n    \t\t\t\t\t\t\t     \n\...
#
#                                               Job Title  \
# 103   Account Executive (Full Set)/Accountant (Up $4...
# 520   Senior Accountant (18 months Contract/Mountbat...
# 594       Chief Accountant (Regional) - $5500 - Central
# 741   Accountant Assistant (Leisure and lifestyle / ...
# 890                  Regional Accountant - Harbourfront
# 961                     Accountant (Financial Analysis)
# 976                                      Tax Accountant
# 1123             Senior Accountant, Accounts Receivable
# 1141  Senior Accountant (Financial Reporting, Tax) -...
# 1484                     Accountant / Senior Accountant
# 1658                                      AP Accountant
# 1729                                         Accountant
# 1806                           Accountant (Fixed Asset)
# 1975             Finance and Admin Executive/Accountant
# 2185                                         Accountant
# 2192  Project Accountant | Cost Controller | Constru...
# 2226         Accountant / Serangoon North l Up to $4500
# 2363  Contract Accounts Executive/Accountant (Health...
# 2577  Accountant/Senior Accountant (6 Months' Contract)
# 2799                                   Group Accountant
#
#                                         Job Description
# 103   Benefits:\n•Working Hours: Monday to Friday 8:...
# 520   Senior Accountant (18 Months contract) \nLocat...
# 594   Handling full functions of finance and account...
# 741   Our client, a well-known Japanese MNC is curre...
# 890   Regional Portfolio\nListed MNC\nExcellent Empl...
# 961   Job Descriptions\n\n\n\nReporting to Senior Ma...
# 976   Responsibilities\n\n\n\n \n\n\n\n\n\t\n\n\t\nA...
# 1123  JOB DESCRIPTION\n\n\n\nThe incumbent will work...
# 1141  Financial and statutory reporting\nEnsure accu...
# 1484  We are looking for a CA or equivalent with pri...
# 1658  Responsible for collecting and checking invoic...
# 1729  Duties:\nConsolidation for group listed on SGX...
# 1806  Responsibilities\n\n\n\n\n\t\n\n\t\nInput jour...
# 1975  Requirements:\n\n\n\n\n\t\nPossess at least a ...
# 2185  Accountants \nJob Scope:\nHandle all aspects o...
# 2192  Reporting to the Finance Manager, the Project ...
# 2226  Accountant \n \nDuration: 2 months (Is convert...
# 2363  Job Scope:\nManage and overseeing daily AP / A...
# 2577  6 Months' Maternity Cover\nEuropean Asset Mana...
# 2799  Description\nHandling the group consolidation ...

# %% [markdown]
# **Check what columns available in the csv.**

# %%
data.columns
# Out:
# Index(['url', 'job_title', 'company', 'job_desc', 'company_desc'], dtype='object')
